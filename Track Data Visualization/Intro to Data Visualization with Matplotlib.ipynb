# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Important: Meet 
# Plots:     http://matplotlib.org/gallery.html
# 3D :       http://matplotlib.org/mpl_toolkit/mplot3d/tutorial.html
# Animation: http://matplotlib.org/api/animation_api.html
# Seaborn:   http://seaborn.pydata.org/examples/index.html

# %%
# # Plotting a figure
# fix, ax = plt.subplots()  # the default is one subplot
# # plt.show()  # shows nothing
# df = pd.read_excel('weather.xlsx').dropna()
# ax.plot(df['month'],df['temp'])
# # The role of market, there are "v", "*", ...
# # The role of line-style, color
# ax.plot(df['month'],df['temp2'], marker = "o", linestyle = '--', color = 'r') 
# ax.set_xlabel('month'); ax.set_ylabel('temprature')
# ax.set_title("Tehran temprature")
# plt.show()

# %%
# # Small Multiples
# fig, ax = plt.subplots(3,2) # 3 rows, 2 columns
# ax[0,0].plot(df['month'],df['temp2'])
# ax[2,1].plot(df['month'],df['temp'], color = 'g')
# plt.show()

# # one-dimension, one axis = 1
# fig, ax = plt.subplots(3,1,sharey=True)     # Y axis will be same for all subplots
# ax[0].plot(df['month'],df['temp2'])
# ax[0].plot(df['month'],df['temp'], color = 'r')
# ax[2].plot(df['month'],df['temp'], color = 'g')
# plt.show()

# %%
# # Example
# # Create a figure and an array of axes: 2 rows, 1 column with shared y axis
# fig, ax = plt.subplots(2, 1, sharey=True)

# # Plot Seattle precipitation data in the top axes
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color = 'b')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color = 'b', linestyle = '--')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color = 'b', linestyle = '--')

# # Plot Austin precipitation data in the bottom axes
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color = 'r')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color = 'r', linestyle = '--')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color = 'r', linestyle = '--')

# plt.show()

# %%
# # Plotting time series
# # Setting read_csv parameter correctly is very important
# df = pd.read_csv('climate_change.csv',parse_dates=['date'], index_col= 'date')
# df.index
# sixties = df["1960-01-01":"1969-12-31"]
# fig, ax = plt.subplots()
# ax.plot(sixties.index, sixties['co2'])
# plt.show()

# %%
# # Plotting two time-series together, the problem of different scales
# fig, ax = plt.subplots()
# ax.plot(df.index, df['co2'],color = 'blue')
# ax.set_xlabel('Time')
# ax.set_ylabel('CO2',color = 'blue')
# ax2 = ax.twinx()
# ax2.plot(df.index, df['relative_temp'],color = 'red')
# ax2.set_ylabel('temprature',color = 'red')
# ax.tick_params('y',colors = 'blue')
# ax2.tick_params('y', colors = 'red')
# # the ticks code is used for setting axes parameters
# plt.show()

# %%
# # Writing the above code functional + Annotating
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     axes.plot(x, y, color = color)
#     axes.set_xlabel(xlabel)
#     axes.set_ylabel(ylabel, color = color)
#     axes.tick_params('y', colors = color)
    
# fig, ax = plt.subplots()
# plot_timeseries(ax, df.index, df['co2'],'blue','Time','CO2 (ppm)')
# ax2 = ax.twinx()
# plot_timeseries(ax2,df.index,df['relative_temp'],'red','Time','Relative Temprature (Celcius)')

# # Annotating 
# ax2.annotate('>1 degree', xy = (pd.Timestamp('2015-10-06'),1))          # Timestamp
# # The code above does not specify the location
# ax2.annotate('>1 degree', xy = (pd.Timestamp('2015-10-06'),1), xytext = (pd.Timestamp('2008-10-06'),-0.2),
#              arrowprops={"arrowstyle" : '->', 'color' : 'gray'})
# plt.show()

# # Can read about annotation in matplotlob.org/users/annotations.html

# %%
# # Bar chart 1
# medals = pd.read_csv('medals_by_country_2016.csv',index_col=0)
# fig, ax = plt.subplots()
# ax.bar(medals.index, medals['Gold'])
# ax.set_ylabel("Number of Medals")
# ax.set_xticklabels(medals.index, rotation = 90)
# plt.show()

# %%
# # Bar chart 2, Cumulative + Legend
# medals = pd.read_csv('medals_by_country_2016.csv',index_col=0)
# fig, ax = plt.subplots()
# ax.bar(medals.index, medals['Gold'], label = 'Gold')
# ax.bar(medals.index, medals['Silver'], bottom = medals['Gold'], label = 'Silver')
# ax.bar(medals.index, medals['Bronze'], bottom = medals['Gold'] + medals['Silver'], label = 'Bronze')
# ax.set_ylabel("Number of Medals")
# ax.set_xticklabels(medals.index, rotation = 90)
# ax.legend()
# plt.show()

# %%
# # Histogram: for showing the distribution of values
# fig, ax = plt.subplots()
# res = pd.read_csv('summer2016.csv')
# mens_gymnastics = res[res['Sport']=='Gymnastics']
# mens_rowing = res[res['Sport']=='Rowing']

# # Barchart Version
# # ax.bar("Rowing", mens_gymnastics['Height'].mean())
# # ax.bar("Gymnastics", mens_rowing['Height'].mean())
# # plt.show()

# Histogram 
# ax.hist(mens_rowing['Height'], label='Rowing', bins=5)      # default # of bins is 10
# ax.hist(mens_gymnastics['Height'], label='Gym', bins=5)
# # Alternatively we can set the bins by numbers. Also, we can change the showing type other than bars
# BIN_list = [150, 160, 170, 180, 190, 200, 210]
# ax.hist(mens_rowing['Height'], label='Rowing', bins=BIN_list, histtype='step')      
# ax.hist(mens_gymnastics['Height'], label='Gym', bins=BIN_list, histtype='step')
# # This "step" model shows more information

# ax.set_xlabel('Height')
# ax.set_ylabel('Number')
# ax.legend()  # for showing the legend
# plt.show()

# %%
# # Statiscal Plotting
# # Adding error bars in barcharts
# fig, ax = plt.subplots()
# ax.bar('Rowing', mens_rowing['Height'].mean(), yerr = mens_rowing['Height'].std())
# ax.bar('Gym', mens_gymnastics['Height'].mean(), yerr = mens_gymnastics['Height'].std())
# ax.set_ylabel("Height")
# plt.show()

# # Adding error bars in plots
# seattle_weather = pd.read_csv('seattle_weather.csv', index_col= 'DATE')
# austin_weather = pd.read_csv('austin_weather.csv', index_col= 'DATE')
# fig, ax = plt.subplots()
# ax.errorbar(seattle_weather.index,seattle_weather['MLY-TAVG-NORMAL'],yerr=seattle_weather['MLY-TAVG-STDDEV'])
# ax.errorbar(austin_weather.index,austin_weather['MLY-TAVG-NORMAL'],yerr=austin_weather['MLY-TAVG-STDDEV'])
# ax.set_ylabel('Temprature (F)')
# plt.show()

# # Adding Box-plot, Candle like Chart, shows 25th, mean, 75th, and 99% confidence data + outliers
# fig, ax = plt.subplots()
# ax.boxplot([mens_rowing['Height'],mens_gymnastics['Height']])
# ax.set_xticklabels(['Rowing', 'Gym'])
# ax.set_ylabel('Height')
# plt.show()

# %%
# # Scatter Plots, for bivariate analysis
# climate_change = pd.read_csv('climate_change.csv',parse_dates=['date'], index_col= 'date')
# fig, ax = plt.subplots()
# ax.scatter(climate_change['co2'],climate_change['relative_temp'])
# plt.show()

# # Part 2
# fig, ax = plt.subplots()
# eighties = climate_change['1980-01-01':'1989-12-31']
# ninties = climate_change['1990-01-01':'1999-12-31']
# ax.scatter(eighties['co2'],eighties['relative_temp'], label = 'eighties', color = 'blue')
# ax.scatter(ninties['co2'],ninties['relative_temp'], label = 'ninties', color = 'red')
# ax.legend()
# ax.set_ylabel('Temperature')
# ax.set_xlabel('co2')
# plt.show()

# # Part 3, encoding by color
# fig, ax = plt.subplots()
# ax.scatter(climate_change['co2'],climate_change['relative_temp'], c = climate_change.index)

# %%
# # Share with others

# plt.style.use('ggplot')     # this line will change the plot format entirely by only one line
# # This style will also apply to all plots in this session until you choose to use another style.
# # more styles: matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# # for examples:
# plt.style.use('bmh')
# plt.style.use('seaborn-colorblind')
# fig, ax = plt.subplots()
# austin_weather = pd.read_csv('austin_weather.csv', index_col= 'DATE')
# ax.plot(austin_weather.index,austin_weather['MLY-TAVG-NORMAL'])
# ax.set_ylabel('Temprature (F)')
# plt.show()

# # going back to default style
# plt.style.use('default')

# # Generally:
# # Dark backgrounds are less visible
# # if colors are important and want to distinguish between them clearly: 'seaborn-colorblind' or ''tableau-colorblind10'
# # for print: consider formats lack background
# # if the printer is black and white: 'grayscale'

# %%
# # Saving your visualization
# medals = pd.read_csv('medals_by_country_2016.csv',index_col=0)
# fig, ax = plt.subplots()
# ax.bar(medals.index, medals['Gold'])
# ax.set_ylabel("Number of Medals")
# ax.set_xticklabels(medals.index, rotation = 90)

# # we can set the size of the figure by:
# fig.set_size_inches([2,4])      # width = 5, height = 3
# # plt.show()
# # Instead of above line, we can save figure by
# fig.savefig('figuregold1.png')  # higher qualiy
# fig.savefig('figuregold2.jpg')  # require less space
# fig.savefig('figuregold3.jpg', qualiy = 50)  # the number is [0,100]
# fig.savefig('figuregold4.svg')      # for working with more advanced graphic software
# fig.savefig('figuregold5.png', dpi = 300)  # dot per inch, control the quality

# %%
# # Automating figures from data:
# summer = pd.read_csv('summer2016.csv',index_col=0)
# sports = summer['Sport'].unique()
# fig, ax = plt.subplots()
# for sport in sports:
#     sport_df = summer[summer['Sport']==sport]
#     ax.bar(sport, sport_df['Height'].mean(), yerr = sport_df['Height'].std())
# ax.set_ylabel("Height")
# ax.set_xticklabels(sports, rotation = 90)
# plt.show()

# # As you see the entire code works automatically.
